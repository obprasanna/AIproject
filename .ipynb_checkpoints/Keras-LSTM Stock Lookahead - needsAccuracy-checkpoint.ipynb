# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import quandl
import statistics

from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from livelossplot import PlotLossesKeras

# free data capture limits for some sources
# Get stock data from tiingo
# Ge treaury data from Quandl
import requests

#You need this for prediction date extraction
import time
from datetime import datetime, date, time, timedelta

nan=np.nan

# %%
DBGmode = 0
WritetoFile = 0
PlotLoss = 0

pd.set_option('display.max_rows', 30)
ticker = 'NVDA'
st_date = '2019-9-23'
en_date = '2020-9-23'

#ex timestep=3, lookahead=2
#for day0,1,2 predict day4
timestep = 3
lookahead = 1

TrainPCT = 0.7

ADDUS10Y = 0

ADDXMA = 0
xmasmall = 7
xmalong = 14

ADDRSI = 0
RSIwindow = 14

ADDSTOCHRSI = 0
SRSIw = 14
SRSIk = 3
SRSId = 3

noofplots = ADDRSI + ADDSTOCHRSI
epochval = 1000 #iter when entire dataset is passed fwd/back thru NN
batchval = 32 #training examples in a singler batch

# %%
us10y_data = quandl.get("FRED/DGS10", start_date=st_date, end_date=en_date, api_key = 'tNjFxT5wYAG7nbemafxi')
us10y_data=us10y_data.reset_index()
us10y_data.rename(columns = {'Value':'US10Y'}, inplace = True) 

if DBGmode==1:
    us10y_data

# %%
for row in range(0,len(us10y_data)):
    us10y_data['Date'][row]=str(us10y_data['Date'][row])[:10]+'T00:00:00.000Z'
us10y_data=us10y_data.set_index('Date')

if DBGmode==1:
    us10y_data
# Out:
# <ipython-input-4-83275a74f87b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us10y_data['Date'][row]=str(us10y_data['Date'][row])[:10]+'T00:00:00.000Z'
# /Users/prasannaob/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
def get_stock_data(stock_symbol, start_date, end_date):
    base_url = f'https://api.tiingo.com/tiingo/daily/{stock_symbol}/prices?'
    token = '59e2dfca5859e44a55ef766a8f81aab1ab8a80e8'
    payload = {
        'startDate': start_date,
        'endDate': end_date,
        'token': token
    }
    response = requests.get(base_url, params=payload)
    return response

# %%
response = get_stock_data(ticker, st_date, en_date)

if DBGmode == 1:
    print(response.url)
    print(response.json())

# %%
def parse_data(data_response):
    json_data = data_response.json()
    dates = []
    closes =[]
    opens = []
    highs = []
    lows = []
    vols = []
    for json_object in json_data:
        dates.append(json_object['date'])
        closes.append(json_object['close'])
        opens.append(json_object['open'])
        highs.append(json_object['high'])
        lows.append(json_object['low'])
        vols.append(json_object['volume'])
    return dates, closes, opens, highs, lows, vols

# %%
dates, closes, opens, highs, lows, vols = parse_data(response)

if DBGmode == 1:
    print(dates, closes)

# %%
#**** Define New Column Label here
datastock = pd.DataFrame(columns = ['Close'], index = dates)
dfindex = datastock.index
dfindex.name = 'Date'

# %%
#**** ADD New Column Data here
datastock['Close']=closes
datastock['Opens']=opens
# datastock['Highs']=highs
# datastock['Lows']=lows
datastock['Vols']=vols
datastock['Close-Diff'] = (2*(datastock['Close'].diff(lookahead)>0).astype(int))-1

if DBGmode == 1:
    datastock

# %%
if DBGmode == 1:
    plt.figure()
    datastock['Close'].plot(figsize=(16,6), label=ticker+'-Close')
    plt.legend()
    plt.show()

# %%
print('Total Stock Rows = ', len(datastock))
print('Total US10Y Rows = ', len(us10y_data))

if ADDUS10Y==1:
    #****APPEND US10Y data here to a separate column in a new dataframe
    data=pd.concat([datastock, us10y_data], axis=1, sort=False)

    #fill US10Y NaN with previous value
    data['US10Y'].fillna(method='ffill', inplace=True)

else:
    data=datastock
    
#data.tail(len(datastock))
data.head(10)
# Out:
# Total Stock Rows =  254
# Total US10Y Rows =  251
#                            Close   Opens      Vols  Close-Diff
# Date
# 2019-09-23T00:00:00.000Z  174.84  172.70   6242800          -1
# 2019-09-24T00:00:00.000Z  172.53  176.10   7931700          -1
# 2019-09-25T00:00:00.000Z  178.23  172.51   7710800           1
# 2019-09-26T00:00:00.000Z  177.34  177.84   5864100          -1
# 2019-09-27T00:00:00.000Z  171.76  175.66   9051400          -1
# 2019-09-30T00:00:00.000Z  174.07  172.80   4654600           1
# 2019-10-01T00:00:00.000Z  174.00  175.00   9150200          -1
# 2019-10-02T00:00:00.000Z  173.04  173.12   7334300          -1
# 2019-10-03T00:00:00.000Z  181.31  173.22  11264700           1
# 2019-10-04T00:00:00.000Z  181.97  181.40   6638100           1

# %%
#Add XMA here

if ADDXMA == 1:
    #Enter SMA Data - defined at the top
    #data['Close-XMA5'] = data.iloc[:,0].rolling(window=xmasmall).mean()
    #data['Close-XMA9'] = data.iloc[:,0].rolling(window=xmalong).mean()

    #Enter EMA Data - defined at the top
    data['Close-XMA'+str(xmasmall)] = data.iloc[:,0].ewm(span=xmasmall, adjust=False).mean()
    data['Close-XMA'+str(xmalong)] = data.iloc[:,0].ewm(span=xmalong, adjust=False).mean()

    droprow=xmalong
    data.drop(data.index[0:droprow], inplace = True)

# %%
def computeRSI(series, period=14):
    # calculating RSI (gives the same values as TradingView)
    # https://stackoverflow.com/questions/20526414/relative-strength-index-in-python-pandas
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    return 100 - 100 / (1 + rs)

# %%
def StochRSI_EMA(series, period=14, smoothK=3, smoothD=3):
    #link from https://gist.github.com/ultragtx/6831eb04dfe9e6ff50d0f334bdcb847d
    # calculating Stoch RSI (gives the same values as TradingView)
    # https://www.tradingview.com/wiki/Stochastic_RSI_(STOCH_RSI) 
    # uses EMA, not SMA
    
    # Calculate RSI
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    rsi = 100 - 100 / (1 + rs)

    # Calculate StochRSI 
    stochrsi  = (rsi - rsi.rolling(period).min()) / (rsi.rolling(period).max() - rsi.rolling(period).min())
    stochrsi_K = stochrsi.ewm(span=smoothK).mean()
    stochrsi_D = stochrsi_K.ewm(span=smoothD).mean()

    return stochrsi, stochrsi_K, stochrsi_D

# %%
#Add RSI here
if ADDRSI == 1:
    data['Close-RSI'+str(RSIwindow)] = computeRSI(data['Close'], RSIwindow)
    #data.drop(data.index[0:RSIwindow], inplace = True)

# %%
#Add STOCHRSI here
if ADDSTOCHRSI == 1:
    srsi_val, srsi_kval, srsi_dval = StochRSI_EMA(data['Close'], SRSIw, SRSIk, SRSId)
    data['Close-SRSIk'+str(SRSIk)] = srsi_kval
    data['Close-SRSId'+str(SRSId)] = srsi_dval
    #data.drop(data.index[0:SRSIw*2], inplace = True)

# %%
#Drop rows on which RSI or SRSI are first computed
if ADDRSI == 1 and ADDSTOCHRSI == 1:
    data.drop(data.index[0:max(RSIwindow,SRSIw*2)], inplace = True)
if ADDRSI == 0 and ADDSTOCHRSI == 1:
    data.drop(data.index[0:SRSIw*2], inplace = True)
if ADDRSI == 1 and ADDSTOCHRSI == 0:
    data.drop(data.index[0:RSIwindow], inplace = True)

# %%
data.tail(len(data))
# Out:
#                            Close     Opens      Vols  Close-Diff
# Date
# 2019-09-23T00:00:00.000Z  174.84  172.7000   6242800          -1
# 2019-09-24T00:00:00.000Z  172.53  176.1000   7931700          -1
# 2019-09-25T00:00:00.000Z  178.23  172.5100   7710800           1
# 2019-09-26T00:00:00.000Z  177.34  177.8400   5864100          -1
# 2019-09-27T00:00:00.000Z  171.76  175.6600   9051400          -1
# ...                          ...       ...       ...         ...
# 2020-09-17T00:00:00.000Z  498.54  485.2894  19812794          -1
# 2020-09-18T00:00:00.000Z  487.57  503.7500  17461548          -1
# 2020-09-21T00:00:00.000Z  500.69  477.0000  18026061           1
# 2020-09-22T00:00:00.000Z  505.51  503.0000  16161302           1
# 2020-09-23T00:00:00.000Z  484.95  503.0200  16175308          -1
#
# [254 rows x 4 columns]

# %%
plt.figure()
data['Close'].plot(figsize=(16,6), label=ticker+'-Close')
if ADDXMA==1:
    data['Close-XMA'+str(xmasmall)].plot(label=ticker+'-EMA'+str(xmasmall))
    data['Close-XMA'+str(xmalong)].plot(label=ticker+'-EMA'+str(xmalong))
plt.legend()
if ADDUS10Y==1:
    data['US10Y'].plot(secondary_y=True, label='US10Y')
plt.legend()
plt.show()

# %%
if noofplots >= 1:
    fig, axs = plt.subplots(noofplots+1,1,figsize=(32,16))
    axs[0].plot(data['Close'], color='r', label=ticker+' Closes')
    if ADDXMA==1:
        axs[0].plot(data['Close-XMA'+str(xmasmall)], label=ticker+' Close-ema'+str(xmasmall))
        axs[0].plot(data['Close-XMA'+str(xmalong)], label=ticker+' Close-ema'+str(xmalong))
    axs[0].legend()
else:
    plt.figure(figsize=(16,6))
    plt.plot(data['Close'], label = ticker+' Closes')
    if ADDXMA==1:
        plt.plot(data['Close-XMA'+str(xmasmall)], label=ticker+' Close-ema'+str(xmasmall))
        plt.plot(data['Close-XMA'+str(xmalong)], label=ticker+' Close-ema'+str(xmalong))
    plt.legend()
    
if ADDRSI==1:
    axs[noofplots].plot(data['Close-RSI'+str(RSIwindow)], label=ticker+' Close-rsi'+str(RSIwindow))
    axs[noofplots].legend()
    noofplots = noofplots - 1
if ADDSTOCHRSI==1:
    axs[noofplots].plot(data['Close-SRSIk'+str(SRSIk)], label=ticker+' Close-srsik'+str(SRSIk))
    axs[noofplots].plot(data['Close-SRSId'+str(SRSId)], label=ticker+' Close-srsid'+str(SRSId))
    axs[noofplots].legend()
plt.show()

# %%
data_noofcols = len(data.columns)
print('Number of data columns = ', data_noofcols)
# Out:
# Number of data columns =  4

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

print('Length of scaled_data = ', len(scaled_data))
print(scaled_data)
# Out:
# Length of scaled_data =  254
# [[7.65978612e-03 4.57126359e-04 8.36703077e-02 0.00000000e+00]
#  [1.91494653e-03 8.63728226e-03 1.34662940e-01 0.00000000e+00]
#  [1.60905247e-02 0.00000000e+00 1.27993349e-01 1.00000000e+00]
#  ...
#  [8.18030341e-01 7.32581080e-01 4.39440037e-01 1.00000000e+00]
#  [8.30017409e-01 7.95135213e-01 3.83137728e-01 1.00000000e+00]
#  [7.78885849e-01 7.95183332e-01 3.83560608e-01 0.00000000e+00]]

# %%
train_length = int(len(scaled_data) * TrainPCT)
test_length = len(scaled_data) - train_length
train_data = scaled_data[0:train_length,:]
test_data = scaled_data[train_length:len(scaled_data),:]

if DBGmode == 1:
    print('scaled_data length =', len(scaled_data))
    print('train_length = ', train_length)
    print('test_length = ', test_length)
    print(train_data)
    print(test_data)

# %%
def create_dataset(dataset, noofcols, timestep=1, lookahead=1):
    #ex timestep=3, lookahead=2
    #for day0,1,2 predict day4
    
    data_x, data_y = [], []
    for i in range(len(dataset) - timestep - lookahead + 1):
        data_x.append(dataset[i:(i+timestep),0:noofcols])
        data_y.append(dataset[i+timestep-1+lookahead,0])
    #It has been shown that Numpy arrays need 4 times less memory compared to Python lists
    return np.array(data_x), np.array(data_y)

# %%
train_x, train_y = create_dataset(train_data, data_noofcols, timestep, lookahead)
test_x, test_y = create_dataset(test_data, data_noofcols, timestep, lookahead)

if DBGmode == 1:
    print(train_x)

# %%
if DBGmode == 1:
    print(train_y)

# %%
print('#Samples, #Timesteps, #Features - for input to LSTM')
print('train_x shape = ', train_x.shape)
print('test_x shape = ', test_x.shape)
print('train_y shape = ', train_y.shape)
print('test_y shape = ', test_y.shape)
# Out:
# #Samples, #Timesteps, #Features - for input to LSTM
# train_x shape =  (174, 3, 4)
# test_x shape =  (74, 3, 4)
# train_y shape =  (174,)
# test_y shape =  (74,)

# %%
##Samples, #Timesteps, #Features - for input to LSTM'
#train_x = np.reshape(train_x, (train_x.shape[0], train_x.shape[1], data_noofcols))
#test_x = np.reshape(test_x, (test_x.shape[0], test_x.shape[1], data_noofcols))

if DBGmode == 1:
    print(test_x)

# %%
if DBGmode == 1:
    print(test_y)

# %%
#optimizer = 'adam' 'SGD' 'RMSprop' 'adadelta' 'adagrad' 'adamax' 'nadam' 'ftrl'
#activation = 'sigmoid' 'linear' relu' 'softmax' 'softplus' 'softsign' 'tanh' selu' 'elu' 'exponential' 
#loss = 'binary_crossentropy' 'mean_squared_error'

#LSTM input_shape = #timestep, #features
model = Sequential()

# model.add(LSTM(256, input_shape=(timestep,data_noofcols)))
# model.add(Dense(1, activation='sigmoid'))

model.add(LSTM(256, return_sequences=True, input_shape=(timestep,data_noofcols)))
model.add(LSTM(256, return_sequences=True))
model.add(LSTM(256, return_sequences=True))
model.add(LSTM(256))
model.add(Dense(1, activation='sigmoid'))

# model.add(LSTM(50, return_sequences=True, input_shape=(timestep,data_noofcols)))
# model.add(LSTM(50, return_sequences=True))
# model.add(LSTM(50, return_sequences=True))
# model.add(LSTM(50))
# model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

print(model.summary())

#model.add(Dense(6, input_dim=6, activation='relu'))
#model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#model.compile(loss='mean_squared_error', optimizer='adam')
#model.add(Dropout(0.2))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 3, 256)            267264
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 3, 256)            525312
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 3, 256)            525312
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# dense (Dense)                (None, 1)                 257
# =================================================================
# Total params: 1,843,457
# Trainable params: 1,843,457
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
if PlotLoss==1:
    model.fit(train_x, train_y, epochs=epochval, batch_size=batchval, validation_data=(test_x, test_y), callbacks=[PlotLossesKeras()])
else:
    model.fit(train_x, train_y, epochs=epochval, batch_size=batchval, validation_data=(test_x, test_y))

score = model.evaluate(train_x, train_y, verbose=0)
print('Keras model loss = ', score[0])
print('Keras model accuracy = ', score[1])

#model.fit(train_x, train_y, epochs=epochval, batch_size=batchval, verbose=1, validation_data=(test_x, test_y), callbacks=[PlotLossesKeras()])
# Out:
# Epoch 1/1000
# 6/6 [==============================] - 1s 166ms/step - loss: 0.1003 - accuracy: 0.0057 - val_loss: 0.0773 - val_accuracy: 0.0000e+00
# Epoch 2/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0455 - accuracy: 0.0057 - val_loss: 0.3776 - val_accuracy: 0.0000e+00
# Epoch 3/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0339 - accuracy: 0.0057 - val_loss: 0.4197 - val_accuracy: 0.0000e+00
# Epoch 4/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0253 - accuracy: 0.0057 - val_loss: 0.2479 - val_accuracy: 0.0000e+00
# Epoch 5/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0158 - accuracy: 0.0057 - val_loss: 0.1869 - val_accuracy: 0.0000e+00
# Epoch 6/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0152 - accuracy: 0.0057 - val_loss: 0.2273 - val_accuracy: 0.0000e+00
# Epoch 7/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0132 - accuracy: 0.0057 - val_loss: 0.2279 - val_accuracy: 0.0000e+00
# Epoch 8/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0119 - accuracy: 0.0057 - val_loss: 0.1440 - val_accuracy: 0.0000e+00
# Epoch 9/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0098 - accuracy: 0.0057 - val_loss: 0.0574 - val_accuracy: 0.0135
# Epoch 10/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0067 - accuracy: 0.0057 - val_loss: 0.0080 - val_accuracy: 0.0135
# Epoch 11/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0043 - accuracy: 0.0057 - val_loss: 0.0079 - val_accuracy: 0.0135
# Epoch 12/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0028 - accuracy: 0.0057 - val_loss: 0.0157 - val_accuracy: 0.0135
# Epoch 13/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0030 - accuracy: 0.0057 - val_loss: 0.0029 - val_accuracy: 0.0135
# Epoch 14/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0027 - accuracy: 0.0057 - val_loss: 0.0098 - val_accuracy: 0.0135
# Epoch 15/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0019 - accuracy: 0.0057 - val_loss: 0.0065 - val_accuracy: 0.0135
# Epoch 16/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0020 - accuracy: 0.0057 - val_loss: 0.0074 - val_accuracy: 0.0135
# Epoch 17/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0018 - accuracy: 0.0057 - val_loss: 0.0020 - val_accuracy: 0.0135
# Epoch 18/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0017 - accuracy: 0.0057 - val_loss: 0.0025 - val_accuracy: 0.0135
# Epoch 19/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0016 - accuracy: 0.0057 - val_loss: 0.0048 - val_accuracy: 0.0135
# Epoch 20/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0016 - accuracy: 0.0057 - val_loss: 0.0022 - val_accuracy: 0.0135
# Epoch 21/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0015 - accuracy: 0.0057 - val_loss: 0.0024 - val_accuracy: 0.0135
# Epoch 22/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0014 - accuracy: 0.0057 - val_loss: 0.0024 - val_accuracy: 0.0135
# Epoch 23/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0014 - accuracy: 0.0057 - val_loss: 0.0026 - val_accuracy: 0.0135
# Epoch 24/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0014 - accuracy: 0.0057 - val_loss: 0.0028 - val_accuracy: 0.0135
# Epoch 25/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0013 - accuracy: 0.0057 - val_loss: 0.0041 - val_accuracy: 0.0135
# Epoch 26/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 0.
1000
# 6/6 [==============================] - 0s 20ms/step - loss: 4.0116e-04 - accuracy: 0.0057 - val_loss: 0.0095 - val_accuracy: 0.0135
# Epoch 984/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 4.0906e-04 - accuracy: 0.0057 - val_loss: 0.0105 - val_accuracy: 0.0135
# Epoch 985/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 3.8510e-04 - accuracy: 0.0057 - val_loss: 0.0085 - val_accuracy: 0.0135
# Epoch 986/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 3.9190e-04 - accuracy: 0.0057 - val_loss: 0.0096 - val_accuracy: 0.0135
# Epoch 987/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 3.8171e-04 - accuracy: 0.0057 - val_loss: 0.0084 - val_accuracy: 0.0135
# Epoch 988/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 3.5508e-04 - accuracy: 0.0057 - val_loss: 0.0077 - val_accuracy: 0.0135
# Epoch 989/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 3.3660e-04 - accuracy: 0.0057 - val_loss: 0.0094 - val_accuracy: 0.0135
# Epoch 990/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 3.5473e-04 - accuracy: 0.0057 - val_loss: 0.0089 - val_accuracy: 0.0135
# Epoch 991/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 3.5005e-04 - accuracy: 0.0057 - val_loss: 0.0084 - val_accuracy: 0.0135
# Epoch 992/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 3.4384e-04 - accuracy: 0.0057 - val_loss: 0.0090 - val_accuracy: 0.0135
# Epoch 993/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 3.4028e-04 - accuracy: 0.0057 - val_loss: 0.0085 - val_accuracy: 0.0135
# Epoch 994/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 3.2609e-04 - accuracy: 0.0057 - val_loss: 0.0089 - val_accuracy: 0.0135
# Epoch 995/1000
# 6/6 [==============================] - 0s 19ms/step - loss: 3.2320e-04 - accuracy: 0.0057 - val_loss: 0.0093 - val_accuracy: 0.0135
# Epoch 996/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 4.2045e-04 - accuracy: 0.0057 - val_loss: 0.0093 - val_accuracy: 0.0135
# Epoch 997/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 3.8780e-04 - accuracy: 0.0057 - val_loss: 0.0091 - val_accuracy: 0.0135
# Epoch 998/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 3.4839e-04 - accuracy: 0.0057 - val_loss: 0.0094 - val_accuracy: 0.0135
# Epoch 999/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 3.2661e-04 - accuracy: 0.0057 - val_loss: 0.0098 - val_accuracy: 0.0135
# Epoch 1000/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 3.1382e-04 - accuracy: 0.0057 - val_loss: 0.0091 - val_accuracy: 0.0135
# Keras model loss =  0.00041519588558003306
# Keras model accuracy =  0.005747126415371895

# %%
train_predictions = model.predict(train_x)
test_predictions = model.predict(test_x)

if DBGmode == 1:
    print(train_predictions)

# %%
#Perform inverse Scaler transform

# create empty table with data_noofcols fields
train_predictions_like = np.zeros(shape=(len(train_predictions), data_noofcols))
# put the predicted values in the right field
train_predictions_like[:,0] = train_predictions[:,0]
# inverse transform and then select the right field
train_predictions = scaler.inverse_transform(train_predictions_like)[:,0]

# create empty table with 2 fields
test_predictions_like = np.zeros(shape=(len(test_predictions), data_noofcols))
# put the predicted values in the right field
test_predictions_like[:,0] = test_predictions[:,0]
# inverse transform and then select the right field
test_predictions = scaler.inverse_transform(test_predictions_like)[:,0]

# %%
if DBGmode == 1:
    print(train_predictions)
    print(test_predictions)

# %%
#train_predict_plot = np.empty_like(scaled_data[:,0])
train_predict_plot = scaled_data[:,0]
train_predict_plot[:] = np.nan
train_predict_plot[timestep-1+lookahead:len(train_predictions)+timestep-1+lookahead] = train_predictions

# %%
if DBGmode==1:
    print(train_predictions)

# %%
test_predict_plot = np.empty_like(scaled_data[:,0])
test_predict_plot[:] = np.nan
test_predict_plot[
    len(train_predictions)+timestep-1+lookahead+timestep-1+lookahead:len(scaled_data)] = test_predictions

# %%
if DBGmode==1:
    print(test_predictions)

# %%
print('Number of data[Close] rows = ', len(data['Close']))
print('Length of Train data = ', len(train_predictions))
print('Length of test data = ', len(test_predictions))
# Out:
# Number of data[Close] rows =  254
# Length of Train data =  174
# Length of test data =  74

# %%
data['AITrain'] = train_predict_plot
data['AITest'] = test_predict_plot
data.head(lookahead+timestep+5)
# Out:
#                            Close   Opens      Vols  Close-Diff     AITrain  \
# Date
# 2019-09-23T00:00:00.000Z  174.84  172.70   6242800          -1         NaN
# 2019-09-24T00:00:00.000Z  172.53  176.10   7931700          -1         NaN
# 2019-09-25T00:00:00.000Z  178.23  172.51   7710800           1         NaN
# 2019-09-26T00:00:00.000Z  177.34  177.84   5864100          -1  182.214058
# 2019-09-27T00:00:00.000Z  171.76  175.66   9051400          -1  183.178779
# 2019-09-30T00:00:00.000Z  174.07  172.80   4654600           1  180.847865
# 2019-10-01T00:00:00.000Z  174.00  175.00   9150200          -1  181.715975
# 2019-10-02T00:00:00.000Z  173.04  173.12   7334300          -1  180.861071
# 2019-10-03T00:00:00.000Z  181.31  173.22  11264700           1  179.879358
#
#                           AITest
# Date
# 2019-09-23T00:00:00.000Z     NaN
# 2019-09-24T00:00:00.000Z     NaN
# 2019-09-25T00:00:00.000Z     NaN
# 2019-09-26T00:00:00.000Z     NaN
# 2019-09-27T00:00:00.000Z     NaN
# 2019-09-30T00:00:00.000Z     NaN
# 2019-10-01T00:00:00.000Z     NaN
# 2019-10-02T00:00:00.000Z     NaN
# 2019-10-03T00:00:00.000Z     NaN

# %%
data.tail(lookahead+timestep+5)
# Out:
#                            Close     Opens      Vols  Close-Diff  AITrain  \
# Date
# 2020-09-11T00:00:00.000Z  486.58  499.4200  15923172          -1      NaN
# 2020-09-14T00:00:00.000Z  514.89  523.2400  30043624           1      NaN
# 2020-09-15T00:00:00.000Z  519.64  531.2000  18188914           1      NaN
# 2020-09-16T00:00:00.000Z  500.58  518.2900  13939985          -1      NaN
# 2020-09-17T00:00:00.000Z  498.54  485.2894  19812794          -1      NaN
# 2020-09-18T00:00:00.000Z  487.57  503.7500  17461548          -1      NaN
# 2020-09-21T00:00:00.000Z  500.69  477.0000  18026061           1      NaN
# 2020-09-22T00:00:00.000Z  505.51  503.0000  16161302           1      NaN
# 2020-09-23T00:00:00.000Z  484.95  503.0200  16175308          -1      NaN
#
#                               AITest
# Date
# 2020-09-11T00:00:00.000Z  487.730148
# 2020-09-14T00:00:00.000Z  486.138570
# 2020-09-15T00:00:00.000Z  518.836785
# 2020-09-16T00:00:00.000Z  503.349100
# 2020-09-17T00:00:00.000Z  465.216361
# 2020-09-18T00:00:00.000Z  482.517224
# 2020-09-21T00:00:00.000Z  545.201714
# 2020-09-22T00:00:00.000Z  526.556373
# 2020-09-23T00:00:00.000Z  498.189143

# %%
plt.figure()
data['Close'].plot(figsize=(16,6), label=ticker+'-Close')
data['AITest'].plot(label='AITest')
data['AITrain'].plot(label='AITrain')
plt.legend()
plt.show()

# %%
plt.figure()
data['Close'][-timestep-20:].plot(figsize=(16,6), label=ticker+'-Close')
data['AITest'][-timestep-20:].plot(label='AITest')
data['AITrain'][-timestep-20:].plot(label='AITrain')
plt.legend()
plt.show()

# %%
data['Abs%Err']=nan
data['DirErr']=nan

# %%
#-----STOCK PRICE PREDICTION METRIC-----
for i in range(len(train_predictions)+timestep-1+lookahead+timestep-1+lookahead,len(scaled_data)):
    data['Abs%Err'][i]=100*(data['AITest'][i]-data['Close'][i])/data['Close'][i]

#-----DIRECTION PREDICTION METRIC-----
for i in range(len(train_predictions)+timestep-1+lookahead+timestep-1+lookahead+1,len(scaled_data)):
    parity=0
    if ((data['Close'][i] - data['Close'][i-1])*(data['AITest'][i] - data['AITest'][i-1])) > 0:
        data['DirErr'][i]=0
        parity=1
    if parity==0:
        data['DirErr'][i]=1

if DBGmode==1:
    print('Train length = ', len(train_predictions)+lookahead)
    print('Total length = ', len(scaled_data))
    ch=len(train_predictions)+timestep-1+lookahead+timestep-1+lookahead+1
    print('data[Close][i-1]   = ', data['Close'][ch-1])
    print('data[Close][i] = ', data['Close'][ch])
    print('data[AITest][i-1]= ', data['AITest'][ch-1])
    print('data[AITest][i]= ', data['AITest'][ch])
    print('data[DirErr][i]  = ', data['DirErr'][ch])
# Out:
# <ipython-input-46-c21109c2eb1a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Abs%Err'][i]=100*(data['AITest'][i]-data['Close'][i])/data['Close'][i]
# <ipython-input-46-c21109c2eb1a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['DirErr'][i]=1
# <ipython-input-46-c21109c2eb1a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['DirErr'][i]=0

# %%
if DBGmode==1:
    print(data['DirErr'][len(train_predictions)+timestep-1+lookahead+timestep-1+lookahead+1:len(scaled_data)])
    print(data['Abs%Err'][len(train_predictions)+timestep-1+lookahead+timestep-1+lookahead:len(scaled_data)])

# %%
Tot_test_error = sum(data['DirErr'][len(train_predictions)+timestep-1+lookahead+timestep-1+lookahead+1:len(scaled_data)])
Tot_test_len = sum(data['DirErr'].notnull())
Test_DirAcc = 100*(Tot_test_len - Tot_test_error) / Tot_test_len
print('timestep=', timestep)
print('lookahead=', lookahead)
print('')
print('----DIRECTION----- \n')
print('Total Test Errors = ', Tot_test_error)
print('Total Test Elements = ', Tot_test_len)
print('Test Direction Predict Accuracy = ', Test_DirAcc)
print('')
print('----STOCK PRICE PREDICTION----- \n')
len(train_predictions)+timestep-1+lookahead+timestep-1+lookahead,len(scaled_data)
print('Max % Price Error = ', max(data['Abs%Err'][len(train_predictions)+timestep-1+lookahead+timestep-1+lookahead:len(scaled_data)]))
print('Min % Price Error = ', min(data['Abs%Err'][len(train_predictions)+timestep-1+lookahead+timestep-1+lookahead:len(scaled_data)]))
print('Average % Price Error = ', statistics.mean(data['Abs%Err'][len(train_predictions)+timestep-1+lookahead+timestep-1+lookahead:len(scaled_data)]))
# Out:
# timestep= 3
# lookahead= 1
#
# ----DIRECTION-----
#
# Total Test Errors =  36.0
# Total Test Elements =  73
# Test Direction Predict Accuracy =  50.68493150684932
#
# ----STOCK PRICE PREDICTION-----
#
# Max % Price Error =  22.26321917879718
# Min % Price Error =  -21.198164812008645
# Average % Price Error =  0.18238656403505427

# %%
print('timestep=', timestep)
print('lookahead', lookahead)
data.tail(2*timestep+10)
# Out:
# timestep= 3
# lookahead 1
#                            Close     Opens      Vols  Close-Diff  AITrain  \
# Date
# 2020-09-01T00:00:00.000Z  552.84  539.2000  12811849           1      NaN
# 2020-09-02T00:00:00.000Z  573.86  588.1500  21850322           1      NaN
# 2020-09-03T00:00:00.000Z  520.62  553.1454  23628151          -1      NaN
# 2020-09-04T00:00:00.000Z  504.90  511.3500  36592071          -1      NaN
# 2020-09-08T00:00:00.000Z  476.52  469.3800  19893237          -1      NaN
# 2020-09-09T00:00:00.000Z  508.60  496.0000  18404957           1      NaN
# 2020-09-10T00:00:00.000Z  492.47  519.5700  17467111          -1      NaN
# 2020-09-11T00:00:00.000Z  486.58  499.4200  15923172          -1      NaN
# 2020-09-14T00:00:00.000Z  514.89  523.2400  30043624           1      NaN
# 2020-09-15T00:00:00.000Z  519.64  531.2000  18188914           1      NaN
# 2020-09-16T00:00:00.000Z  500.58  518.2900  13939985          -1      NaN
# 2020-09-17T00:00:00.000Z  498.54  485.2894  19812794          -1      NaN
# 2020-09-18T00:00:00.000Z  487.57  503.7500  17461548          -1      NaN
# 2020-09-21T00:00:00.000Z  500.69  477.0000  18026061           1      NaN
# 2020-09-22T00:00:00.000Z  505.51  503.0000  16161302           1      NaN
# 2020-09-23T00:00:00.000Z  484.95  503.0200  16175308          -1      NaN
#
#                               AITest    Abs%Err  DirErr
# Date
# 2020-09-01T00:00:00.000Z  508.295128  -8.057462     0.0
# 2020-09-02T00:00:00.000Z  452.212211 -21.198165     1.0
# 2020-09-03T00:00:00.000Z  454.725082 -12.657008     1.0
# 2020-09-04T00:00:00.000Z  485.043995  -3.932661     1.0
# 2020-09-08T00:00:00.000Z  451.580345  -5.233706     0.0
# 2020-09-09T00:00:00.000Z  521.732745   2.582136     0.0
# 2020-09-10T00:00:00.000Z  509.676156   3.493849     0.0
# 2020-09-11T00:00:00.000Z  487.730148   0.236374     0.0
# 2020-09-14T00:00:00.000Z  486.138570  -5.583995     1.0
# 2020-09-15T00:00:00.000Z  518.836785  -0.154571     0.0
# 2020-09-16T00:00:00.000Z  503.349100   0.553178     0.0
# 2020-09-17T00:00:00.000Z  465.216361  -6.684246     0.0
# 2020-09-18T00:00:00.000Z  482.517224  -1.036318     1.0
# 2020-09-21T00:00:00.000Z  545.201714   8.890075     0.0
# 2020-09-22T00:00:00.000Z  526.556373   4.163394     1.0
# 2020-09-23T00:00:00.000Z  498.189143   2.730002     0.0

# %%
if WritetoFile == 1:
    data.to_csv(ticker+'_predict.csv')
    print('Wrote to file')

# %%
if DBGmode == 1:
    pd.set_option('display.max_rows', data.shape[0]+1)
    data
